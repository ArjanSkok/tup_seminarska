# %%
import datetime
import numpy as np
import pandas as pd
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

# %%
df = pd.read_csv("./data/cleaned.csv")

print(df.head())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-12-01 00:37:35   2022-12-01 00:47:35              1.0
# 1         1  2022-12-01 00:34:35   2022-12-01 00:55:21              0.0
# 2         1  2022-12-01 00:33:26   2022-12-01 00:37:34              1.0
# 3         1  2022-12-01 00:45:51   2022-12-01 00:53:16              1.0
# 4         2  2022-12-01 00:49:49   2022-12-01 00:54:13              1.0
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           2.00         1.0           170           237             1
# 1           8.40         1.0           138           141             2
# 2           0.80         1.0           140           140             1
# 3           3.00         1.0           141            79             3
# 4           0.76         1.0           261           231             1
#
#    fare_amount  extra  tip_amount  tolls_amount  total_amount  airport_fee
# ...

# %%
#df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
monthpick = pd.to_datetime(df['tpep_pickup_datetime']).dt.month
monthdrop = pd.to_datetime(df['tpep_dropoff_datetime']).dt.month
df = df.loc[monthpick == 12]
df = df.loc[monthdrop == 12]
print(df)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-12-01 00:37:35   2022-12-01 00:47:35              1.0
# 1               1  2022-12-01 00:34:35   2022-12-01 00:55:21              0.0
# 2               1  2022-12-01 00:33:26   2022-12-01 00:37:34              1.0
# 3               1  2022-12-01 00:45:51   2022-12-01 00:53:16              1.0
# 4               2  2022-12-01 00:49:49   2022-12-01 00:54:13              1.0
# ...           ...                  ...                   ...              ...
# 3245758         2  2022-12-31 23:36:15   2022-12-31 23:52:36              1.0
# 3245759         2  2022-12-31 23:09:34   2022-12-31 23:17:46              1.0
# 3245760         2  2022-12-31 23:39:06   2022-12-31 23:51:55              1.0
# 3245761         2  2022-12-31 23:09:37   2022-12-31 23:23:07              1.0
# 3245762         2  2022-12-31 23:34:24   2022-12-31 23:40:52              1.0
#
# ...

# %%
df['datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
print(df['datetime'].dt.date)
# Out:
# 0          2022-12-01
# 1          2022-12-01
# 2          2022-12-01
# 3          2022-12-01
# 4          2022-12-01
#               ...
# 3245758    2022-12-31
# 3245759    2022-12-31
# 3245760    2022-12-31
# 3245761    2022-12-31
# 3245762    2022-12-31
# Name: datetime, Length: 3245146, dtype: object

# %%
df['date'] = df['datetime'].dt.date
df['hour'] = df['datetime'].dt.hour
print(df)
#aggregated = df.groupby(df['datetime'].dt.hours)['total_amount'].agg(['sum', 'mean', 'max'])
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-12-01 00:37:35   2022-12-01 00:47:35              1.0
# 1               1  2022-12-01 00:34:35   2022-12-01 00:55:21              0.0
# 2               1  2022-12-01 00:33:26   2022-12-01 00:37:34              1.0
# 3               1  2022-12-01 00:45:51   2022-12-01 00:53:16              1.0
# 4               2  2022-12-01 00:49:49   2022-12-01 00:54:13              1.0
# ...           ...                  ...                   ...              ...
# 3245758         2  2022-12-31 23:36:15   2022-12-31 23:52:36              1.0
# 3245759         2  2022-12-31 23:09:34   2022-12-31 23:17:46              1.0
# 3245760         2  2022-12-31 23:39:06   2022-12-31 23:51:55              1.0
# 3245761         2  2022-12-31 23:09:37   2022-12-31 23:23:07              1.0
# 3245762         2  2022-12-31 23:34:24   2022-12-31 23:40:52              1.0
#
# ...

# %%
date_picker = widgets.DatePicker(
    description='Pick a Date',
    value=df['date'].min(),  # Set default value to the minimum date in your dataset
)

# Function to update and display the DataFrame based on the selected date
def update_data(date):
    filtered_df = df[df['date'] == date]
    display(filtered_df)
    print('a')

# Connect the date picker to the update function
widgets.interactive(update_data, date=date_picker)
# Out:
# interactive(children=(DatePicker(value=datetime.date(2022, 12, 1), description='Pick a Date', step=1), Output(…

# %%
print(dates)
# Out:
# 0

# %%
i = 0
for date in df.groupby([df['datetime'].dt.date])["total_amount"].mean():
    for hour in df.groupby([df['datetime'].dt.hour])["total_amount"].mean():
        print(hour)
        i += 1

#aggregated = df.groupby(df['datetime'].dt.date)['total_amount'].agg(['sum', 'mean', 'max'])[1:]
# Out:
# 26.25302778506389
# 24.694841987114078
# 22.7483060342888
# 23.426737855210934
# 28.277093054153163
# 32.23234119345524
# 25.338365536384913
# 23.123668180823117
# 22.42112962352165
# 22.45723872181855
# 22.464135542438637
# 22.73463138709811
# 23.060363281271137
# 23.82313281872431
# 24.547560198209556
# 25.082157914462186
# 26.690307796406284
# 26.873988810740133
# 26.06373607006071
# 25.286399173919456
# 24.738623451675274
# 23.945774312734407
# 24.38344703013517
# 25.800545276684986
# 26.25302778506389
# 24.694841987114078
# 22.7483060342888
# 23.426737855210934
# 28.277093054153163
# 32.23234119345524
# 25.338365536384913
# 23.123668180823117
# 22.42112962352165
# 22.45723872181855
# 22.464135542438637
# 22.73463138709811
# 23.060363281271137
# 23.82313281872431
# 24.547560198209556
# 25.082157914462186
# 26.690307796406284
# 26.873988810740133
# 26.06373607006071
# 25.286399173919456
# 24.738623451675274
# 23.945774312734407
# 24.38344703013517
# 25.800545276684986
# ...
